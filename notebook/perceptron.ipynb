# %%
import numpy as np
import matplotlib.pyplot as plt

from sklearn.datasets import make_blobs
from sklearn.metrics import accuracy_score
from sklearn.linear_model import Perceptron

# %%
X, y = make_blobs(n_samples = 100, n_features = 2, centers = 2, random_state = 0)
y = y.reshape((y.shape[0], 1))

plt.scatter(X[:, 0], X[:, 1], c = y, cmap = "summer")

# %%
def initialisation(X):
    W = np.random.randn(X.shape[1], 1)
    b = np.random.randn(1)
    return (W, b)

# %%
W, b = initialisation(X)

# %%
def model(X, W, b):
    Z = X.dot(W + b)
    A = 1 / (1 + np.exp(-Z))
    return A

# %%
A = model(X, W, b)

# %%
def log_loss(A, y):
    return 1 / len(y) * np.sum(-y * np.log(A) - (1 - y) * np.log(1 - A))

# %%
log_loss(A, y)
# Out:
# 0.5410420230169021

# %%
def gradients(A, X, y):
    dW = 1 / len(y) * np.dot(X.T, A - y)
    db = 1 / len(y) * np.sum(A - y)
    return (dW, db)

# %%
dW, db = gradients(A, X, y)

# %%
def update(dW, db, W, b, learning_rate):
    W -= learning_rate * dW
    b -= learning_rate * db 
    return (W, b)

# %%
def predict(X, W, b):
    A = model(X, W, b)
    return A >= 0.5

# %%
def perceptron(X, y, learning_rate = 0.1, n_iter = 100):
    W, b = initialisation(X)
    Loss = []
    for i in range(n_iter):
        A = model(X, W, b)
        Loss.append(log_loss(A, y))
        dW, db = gradients(A, X, y)
        W, b = update(dW, db, W, b, learning_rate)
    
    y_pred = predict(X, W, b)
    print(accuracy_score(y, y_pred))
    plt.plot(Loss)

    return (W, b)

# %%
W, b = perceptron(X, y)
# Out:
# 0.86

# %%
sp = Perceptron()
sp.fit(X, y)

w1, w2 = sp.coef_[0]
b_1 = sp.intercept_[0]
# Out:
# /home/yannt/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
new = np.array([2, 1])
x0 = np.linspace(-1, 4, 100)
x1 = ( - W[0] *  x0 - b ) /  W[1]

x_2 = ( - w1 *  x0 - b_1 ) /  w1

plt.scatter(X[:, 0], X[:, 1], c = y, cmap = "summer")
plt.scatter(new[0], new[1], c='r')
plt.plot(x0, x_2, c='red')
plt.plot(x0, x1, c = 'orange', lw = 3)
predict(new, W, b)
# Out:
# array([ True])

# %%
import matplotlib.pyplot as plt
from mlxtend.plotting import plot_decision_regions

# Tracer la frontière de décision
plot_decision_regions(X, y.ravel(), clf=sp, legend=2)

# Ajouter des titres et des étiquettes d'axe
plt.title('Frontière de décision du perceptron')
plt.xlabel('Fonctionnalité 1')
plt.ylabel('Fonctionnalité 2')

# Afficher le graphique
plt.show()

# %%
def initialisation(X):
    W = np.random.randn(X.shape[1], 1)
    b = np.random.randn(1)
    return (W, b)

def model(X, W, b):
    Z = X.dot(W + b)
    A = 1 / (1 + np.exp(-Z))
    return A



def log_loss(A, y):
    return 1 / len(y) * np.sum(-y * np.log(A) - (1 - y) * np.log(1 - A))

def gradients(A, X, y):
    dW = 1 / len(y) * np.dot(X.T, A - y)
    db = 1 / len(y) * np.sum(A - y)
    return (dW, db)

def update(dW, db, W, b, learning_rate):
    W -= learning_rate * dW
    b -= learning_rate * db 
    return (W, b)


def predict(X, W, b):
    A = model(X, W, b)
    return A >= 0.5

def perceptron(X, y, learning_rate = 0.1, n_iter = 100):
    W, b = initialisation(X)
    Loss = []
    for i in range(n_iter):
        A = model(X, W, b)
        Loss.append(log_loss(A, y))
        dW, db = gradients(A, X, y)
        W, b = update(dW, db, W, b, learning_rate)
    
    y_pred = predict(X, W, b)
    print(accuracy_score(y, y_pred))
    plt.plot(Loss)

    return (W, b)

# %%
import numpy as np 
import matplotlib.pyplot as plt

import warnings


from sklearn.linear_model import Perceptron as skPerceptron
from sklearn.datasets import load_iris, make_blobs
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score   
iris = load_iris()

X = iris.data[:, (0, 1)]  # petal length, petal width
y = (iris.target == 0).astype(np.int32)
y = y.reshape((y.shape[0], 1))
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=42)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /home/yannt/OneDrive/Documents/1_PARIS_SACLAY/1_machine_learning/machine_learning_course/notebook/perceptron.ipynb Cell 21 line 8
#       <a href='vscode-notebook-cell:/home/yannt/OneDrive/Documents/1_PARIS_SACLAY/1_machine_learning/machine_learning_course/notebook/perceptron.ipynb#X26sZmlsZQ%3D%3D?line=3'>4</a> import warnings
#       <a href='vscode-notebook-cell:/home/yannt/OneDrive/Documents/1_PARIS_SACLAY/1_machine_learning/machine_learning_course/notebook/perceptron.ipynb#X26sZmlsZQ%3D%3D?line=6'>7</a> from sklearn.linear_model import Perceptron as skPerceptron
# ----> <a href='vscode-notebook-cell:/home/yannt/OneDrive/Documents/1_PARIS_SACLAY/1_machine_learning/machine_learning_course/notebook/perceptron.ipynb#X26sZmlsZQ%3D%3D?line=7'>8</a> from src.perceptron import Perceptron
#       <a href='vscode-notebook-cell:/home/yannt/OneDrive/Documents/1_PARIS_SACLAY/1_machine_learning/machine_learning_course/notebook/perceptron.ipynb#X26sZmlsZQ%3D%3D?line=8'>9</a> from sklearn.datasets import load_iris, make_blobs
#      <a href='vscode-notebook-cell:/home/yannt/OneDrive/Documents/1_PARIS_SACLAY/1_machine_learning/machine_learning_course/notebook/perceptron.ipynb#X26sZmlsZQ%3D%3D?line=9'>10</a> from sklearn.model_selection import train_test_split
#
# ModuleNotFoundError: No module named 'src'
